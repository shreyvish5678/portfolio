# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# %%
noise = tf.random.normal(shape=(1, 128), mean=0.0, stddev=1.0)
plt.imshow(noise, cmap='gray')
plt.axis('off')
plt.show()

# %%
dog_model = load_model('../MODELS/generator.h5')
dog_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_47 (Dense)            (None, 8192)              1048576
#
#  batch_normalization_101 (B  (None, 8192)              32768
#  atchNormalization)
#
#  leaky_re_lu_161 (LeakyReLU  (None, 8192)              0
#  )
#
#  reshape_27 (Reshape)        (None, 4, 4, 512)         0
#
#  conv2d_transpose_104 (Conv  (None, 8, 8, 256)         3276800
#  2DTranspose)
#
#  batch_normalization_102 (B  (None, 8, 8, 256)         1024
#  atchNormalization)
#
#  leaky_re_lu_162 (LeakyReLU  (None, 8, 8, 256)         0
#  )
#
#  conv2d_transpose_105 (Conv  (None, 16, 16, 128)       819200
#  2DTranspose)
#
#  batch_normalization_103 (B  (None, 16, 16, 128)       512
#  atchNormalization)
#
#  leaky_re_lu_163 (LeakyReLU  (None, 16, 16, 128)       0
#  )
#
#  conv2d_transpose_106 (Conv  (None, 32, 32, 64)        204800
#  2DTranspose)
#
#  batch_normalization_104 (B  (None, 32, 32, 64)        256
#  atchNormalization)
#
#  leaky_re_lu_164 (LeakyReLU  (None, 32, 32, 64)        0
#  )
#
#  conv2d_transpose_107 (Conv  (None, 64, 64, 3)         4800
#  2DTranspose)
#
# =================================================================
# Total params: 5388736 (20.56 MB)
# Trainable params: 5371456 (20.49 MB)
# Non-trainable params: 17280 (67.50 KB)
# _________________________________________________________________

# %%
dog_image = dog_model(noise, training=False)*0.5 + 0.5
plt.imshow(dog_image[0])
plt.axis('off')
plt.show()
