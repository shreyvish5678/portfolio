# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# %%
model = load_model('../MODELS/human_face_generator.h5')
model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 49152)             4915200
#
#  reshape_1 (Reshape)         (None, 128, 128, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 128)     6144
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 128)       262144
#
#  batch_normalization_9 (Bat  (None, 64, 64, 128)       512
#  chNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)       524288
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 256)       1048576
#
#  batch_normalization_10 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 32, 32, 256)       0
#
#  conv2d_transpose_8 (Conv2D  (None, 32, 32, 512)       2097152
#  Transpose)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 512)       4194304
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 16, 16, 512)       0
#
#  conv2d_transpose_9 (Conv2D  (None, 16, 16, 512)       4194304
#  Transpose)
#
#  conv2d_transpose_10 (Conv2  (None, 32, 32, 512)       4194304
#  DTranspose)
#
#  batch_normalization_11 (Ba  (None, 32, 32, 512)       2048
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 32, 32, 512)       0
#
#  conv2d_transpose_11 (Conv2  (None, 32, 32, 256)       2097152
#  DTranspose)
#
#  conv2d_transpose_12 (Conv2  (None, 64, 64, 256)       1048576
#  DTranspose)
#
#  batch_normalization_12 (Ba  (None, 64, 64, 256)       1024
#  tchNormalization)
#
#  conv2d_transpose_13 (Conv2  (None, 128, 128, 128)     524288
#  DTranspose)
#
#  conv2d_transpose_14 (Conv2  (None, 128, 128, 128)     262144
#  DTranspose)
#
#  batch_normalization_13 (Ba  (None, 128, 128, 128)     512
#  tchNormalization)
#
#  conv2d_transpose_15 (Conv2  (None, 128, 128, 3)       6147
#  DTranspose)
#
# =================================================================
# Total params: 25379843 (96.82 MB)
# Trainable params: 25377283 (96.81 MB)
# Non-trainable params: 2560 (10.00 KB)
# _________________________________________________________________

# %%
noise = tf.random.normal(shape=(1, 100), mean=0.0, stddev=1.0)
noise_reshaped = tf.reshape(noise, shape=(10, 10))
plt.imshow(noise_reshaped, cmap='gray')
plt.axis('off')
plt.show()

# %%
face = model(noise, training=False)*0.5 + 0.5
plt.imshow(face[0])
plt.axis('off')
plt.show()
